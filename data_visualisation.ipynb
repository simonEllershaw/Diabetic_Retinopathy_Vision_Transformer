# %% [markdown]
# # Dataset Visulisation
# This notebook loads and visualises samples from each dataset used in this project

# %%
import matplotlib.pyplot as plt
import random

# %% [markdown]
# ## EyePACs
#
# The main training set

# %%
from datasets.eyePACS import EyePACS_Dataset

dataset_eyePACs = EyePACS_Dataset(os.path.join("data", "eyePACs"), random_state=13)
print(f"Size of dataset: {len(dataset_eyePACs)}")
dataset_eyePACs.visualise_sample(random.randint(0, len(dataset_eyePACs)))
plt.show()
# Out:
# Size of dataset: 28134

# %% [markdown]
# ## Messidor-1
#
# External validation set

# %%
from datasets.messidor import Messidor_Dataset

dataset_messidor = Messidor_Dataset(os.path.join("data", "messidor"))
print(f"Size of dataset: {len(dataset_messidor)}")
dataset_messidor.visualise_sample(random.randint(0, len(dataset_messidor)))
plt.show()
# Out:
# Size of dataset: 1044

# %% [markdown]
# ## IDRiD
#
# Pixel level retinal lesion annoations. Used for explainability analysis

# %%
from datasets.IDRiD import IDRiD_Dataset

dataset_IDRiD = IDRiD_Dataset(os.path.join("data", "idrid"))
print(f"Size of dataset: {len(dataset_IDRiD)}")
dataset_IDRiD.visualise_sample(random.randint(0, len(dataset_IDRiD)))
plt.show()
# Out:
# Size of dataset: 81

# %% [markdown]
# ## Masked eyePACs
# Random mask added to healthy eyePACs images. Used to check ViTs can detect sub token level features

# %%
from datasets.eyePACS_masked import EyePACS_Masked_Dataset

dataset_eyePACS_masked = EyePACS_Masked_Dataset(os.path.join("data", "eyePACs"), mask_size=4, random_state=13)
print(f"Size of dataset: {len(dataset_eyePACS_masked)}")
dataset_eyePACS_masked.visualise_sample(random.randint(0, len(dataset_eyePACS_masked)))
plt.show()
# Out:
# Size of dataset: 28134
